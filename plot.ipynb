# %%
import sys
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from google.colab import drive
drive.mount('/content/gdrive')

df_variable_shards=pd.read_csv('gdrive/My Drive/shard_all.csv')

nb_req_5=pd.read_csv('gdrive/My Drive/loop_val_5.csv')

nb_req_50=pd.read_csv('gdrive/My Drive/loop_val_50.csv')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
df_variable_shards
# Out:
#     nb_shards  nb_requests  accuracy  retraining_time
# 0           5            0  0.973516        61.959930
# 1           5            1  0.972810        13.154224
# 2           5            2  0.972617        25.471269
# 3           5            3  0.973131        24.927469
# 4           5            4  0.973163        37.026351
# ..        ...          ...       ...              ...
# 75         25           55  0.955635        58.063605
# 76         25           60  0.956021        51.609082
# 77         25           65  0.955892        54.580034
# 78         25           70  0.955154        61.225946
# 79         25           75  0.955507        59.052519
#
# [80 rows x 4 columns]

# %%
nb_req_5
# Out:
#    nb_shards  nb_requests  accuracy  retraining_time
# 0          5            0  0.956984        16.777748
# 1          5            1  0.956631         3.534082
# 2          5            2  0.956470         6.614682
# 3          5            3  0.956310        10.212859
# 4          5            4  0.955700         9.931817
# 5          5            5  0.955796        10.383199

# %%
nb_req_50
# Out:
#     nb_shards  nb_requests  accuracy  retraining_time
# 0           5            0  0.956021        15.693425
# 1           5            1  0.956502         3.390159
# 2           5            2  0.956663         6.260382
# 3           5            3  0.957112         7.241405
# 4           5            4  0.956534        13.257044
# 5           5            5  0.956887         9.666190
# 6           5            6  0.955796        13.360294
# 7           5            7  0.956374        13.465196
# 8           5            8  0.956374         9.268769
# 9           5            9  0.956053        13.984915
# 10          5           10  0.956245        16.744542
# 11          5           11  0.956117        16.263931
# 12          5           12  0.955892        15.984922
# 13          5           13  0.955924        12.890157
# 14          5           14  0.955379        16.215484
# 15          5           15  0.955668        15.801786
# ...

# %%
nb_req_100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-99004936ac18> in <module>()
# ----> 1 nb_req_100
#
# NameError: name 'nb_req_100' is not defined

# %%
import pandas as pd
import numpy as np
import seaborn as sns 

#fig = plt.figure()
#ax = fig.add_subplot(111)
#x = [a['nb_request'] for a in df]
#y = [a['accuracy'] for a in df]
#z = [a['retraining_time'] for a in df]

colors = {'5':'red'}

#number of shards = 5

n = nb_req_5['nb_shards']
x = nb_req_5['nb_requests']
y = nb_req_5['accuracy']
z = nb_req_5['retraining_time']

#df['nb_shards'] = np.random.choice(z, 80)
#ax.set_xlabel('nb_request')
#ax.set_ylabel('accuracy')

sns.scatterplot(x, y)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
import pandas as pd
import numpy as np
import seaborn as sns 

colors = {'5':'red'}
#number of shards = 5

n = nb_req_50['nb_shards']
x2 = nb_req_50['nb_requests']
y2 = nb_req_50['accuracy']
z2 = nb_req_50['retraining_time']

#df['nb_shards'] = np.random.choice(z, 80)
#ax.set_xlabel('nb_request')
#ax.set_ylabel('accuracy')

sns.scatterplot(x2, y2)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(x2, z2)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
max = 50
nb_req_50['group'] = nb_req_50.groupby(pd.cut(nb_req_50['nb_requests'],
                 range(-1, len(nb_req_50) - 1, 10)))['accuracy'].transform('mean')
print(nb_req_50)
print("\n")
avg_accuracy = mean(nb_req_50['accuracy'])
print("Average accuracy for 50 unlearning request is ", avg_accuracy)
# Out:
#     nb_shards  nb_requests  accuracy  retraining_time     group
# 0           5            0  0.956021        15.693425  0.956432
# 1           5            1  0.956502         3.390159  0.956432
# 2           5            2  0.956663         6.260382  0.956432
# 3           5            3  0.957112         7.241405  0.956432
# 4           5            4  0.956534        13.257044  0.956432
# 5           5            5  0.956887         9.666190  0.956432
# 6           5            6  0.955796        13.360294  0.956432
# 7           5            7  0.956374        13.465196  0.956432
# 8           5            8  0.956374         9.268769  0.956432
# 9           5            9  0.956053        13.984915  0.956432
# 10          5           10  0.956245        16.744542  0.956139
# 11          5           11  0.956117        16.263931  0.956139
# 12          5           12  0.955892        15.984922  0.956139
# 13          5           13  0.955924        12.890157  0.956139
# ...

# %%
import seaborn as sns
sns.scatterplot(nb_req_50['nb_requests'], nb_req_50['group'])

# %% [markdown]
# Processing 100 unlearning requests on a data with data size reduced to 10000 for the existing model
# This makes the unlearning request as 1% of the total data size and analyze the performance

# %%
import sys
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from google.colab import drive
drive.mount('/content/gdrive')

nb_req_1per = pd.read_csv('gdrive/My Drive/100_unlearning.csv')

import pandas as pd
import numpy as np
import seaborn as sns 

#number of shards = 5

n = nb_req_1per['nb_shards']
x2 = nb_req_1per['nb_requests']
y2 = nb_req_1per['accuracy']
z2 = nb_req_1per['retraining_time']

#df['nb_shards'] = np.random.choice(z, 80)
#ax.set_xlabel('nb_request')
#ax.set_ylabel('accuracy')

sns.scatterplot(x2, y2)

plt.show()
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
import sys
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from google.colab import drive
drive.mount('/content/gdrive')

one_percent_nbreq_orginal_data = pd.read_csv('gdrive/My Drive/1_percent_nbreq_orginal-data.csv')

import pandas as pd
import numpy as np
import seaborn as sns 

#number of shards = 5

n = one_percent_nbreq_orginal_data['nb_shards']
x2 = one_percent_nbreq_orginal_data['nb_requests']
y2 = one_percent_nbreq_orginal_data['accuracy']
z2 = one_percent_nbreq_orginal_data['retraining_time']

#df['nb_shards'] = np.random.choice(z, 80)
#ax.set_xlabel('nb_request')
#ax.set_ylabel('accuracy')

sns.scatterplot(x2, y2)

plt.show()
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
from numpy.ma.core import mean
import pandas as pd
import numpy as np
import seaborn as sns 
max = 2500
one_percent_nbreq_orginal_data['accuracy_groups'] = one_percent_nbreq_orginal_data.groupby(pd.cut(one_percent_nbreq_orginal_data['nb_requests'],
                 range(-1, len(one_percent_nbreq_orginal_data) - 1, 100)))['accuracy'].transform('mean')
print(one_percent_nbreq_orginal_data)

one_percent_nbreq_orginal_data
# Out:
#       nb_shards  nb_requests  accuracy  retraining_time  accuracy_groups
# 0             5            0  0.955924        16.767089         0.956125
# 1             5            1  0.955507         2.976110         0.956125
# 2             5            2  0.955892         3.772871         0.956125
# 3             5            3  0.955379         5.815129         0.956125
# 4             5            4  0.956053         6.739929         0.956125
# ...         ...          ...       ...              ...              ...
# 2488          5         2488  0.956021        16.222818              NaN
# 2489          5         2489  0.956117        15.945051              NaN
# 2490          5         2490  0.957144        15.869228              NaN
# 2491          5         2491  0.956213        16.375571              NaN
# 2492          5         2492  0.956502        16.137899              NaN
#
# [2493 rows x 5 columns]
# ...

# %%
import seaborn as sns
sns.scatterplot(one_percent_nbreq_orginal_data['nb_requests'], one_percent_nbreq_orginal_data['accuracy_groups'])

print("\n")
avg_accuracy = mean(one_percent_nbreq_orginal_data['accuracy'])
print("Average accuracy for 2500 unlearning request is ", avg_accuracy)
print("\n")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Average accuracy for 2500 unlearning request is  0.9560795330453246

# %%
from numpy.ma.core import mean
import pandas as pd
import numpy as np
import seaborn as sns 
max = 100
nb_req_1per['group'] = nb_req_1per.groupby(pd.cut(nb_req_1per['nb_requests'],
                 range(-1, len(nb_req_1per) - 1, 10)))['accuracy'].transform('mean')
print(nb_req_1per)


import seaborn as sns
sns.scatterplot(nb_req_1per['nb_requests'], nb_req_1per['group'])

avg_accuracy = mean(nb_req_1per['accuracy'])
print("Average accuracy for 100 unlearning request is ", avg_accuracy)

# %%
import sys
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from google.colab import drive
drive.mount('/content/gdrive')

nb_req_5per = pd.read_csv('gdrive/My Drive/500_nb_req.csv')

import pandas as pd
import numpy as np
import seaborn as sns 

#number of shards = 5

x3 = nb_req_5per['nb_requests']
y3 = nb_req_5per['accuracy']
z3 = nb_req_5per['retraining_time']

#df['nb_shards'] = np.random.choice(z, 80)
#ax.set_xlabel('nb_request')
#ax.set_ylabel('accuracy')

sns.scatterplot(x3, y3)

plt.show()
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
from numpy.ma.core import mean
import pandas as pd
import numpy as np
import seaborn as sns 
max = 500
nb_req_5per['accuracy_groups'] = nb_req_5per.groupby(pd.cut(nb_req_5per['nb_requests'],
                 range(-1, len(nb_req_5per) - 1, 50)))['accuracy'].transform('mean')
print(nb_req_5per)

nb_req_5per
# Out:
#      nb_shards  nb_requests  accuracy  retraining_time  accuracy_group  \
# 0            5            0  0.956149        21.044650        0.956135
# 1            5            1  0.956823         3.213796        0.956135
# 2            5            2  0.956342        14.475054        0.956135
# 3            5            3  0.956117        18.206115        0.956135
# 4            5            4  0.956502        13.341977        0.956135
# ..         ...          ...       ...              ...             ...
# 496          5          496  0.956663        16.492290        0.956036
# 497          5          497  0.955475        17.442174        0.956036
# 498          5          498  0.956053        17.831155        0.956036
# 499          5          499  0.955314        17.915707        0.956036
# 500          5          500  0.955828        18.633966             NaN
#
#      accuracy_groups
# 0           0.956135
# 1           0.956135
# 2           0.956135
# 3           0.956135
# ...

# %%
import seaborn as sns
sns.scatterplot(nb_req_5per['nb_requests'], nb_req_5per['accuracy_groups'])

print("\n")
avg_accuracy = mean(nb_req_5per['accuracy'])
print("Average accuracy for 500 unlearning request is ", avg_accuracy)
print("\n")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Average accuracy for 500 unlearning request is  0.9560607205222952

# %%
import pandas as pd
import numpy as np
import seaborn as sns 

#fig = plt.figure()
#ax = fig.add_subplot(111)
#x = [a['nb_request'] for a in df]
#y = [a['accuracy'] for a in df]
#z = [a['retraining_time'] for a in df]

colors = {'5':'red', '10':'blue', '15':'green', '20':'yellow', '25':'hotpink'}

n = df['nb_shards']
x = df['nb_requests']
y = df['accuracy']
z = df['retraining_time']

#df['nb_shards'] = np.random.choice(z, 80)
#ax.set_xlabel('nb_request')
#ax.set_ylabel('accuracy')

sns.scatterplot(x, y, hue=df['nb_shards'], cmap='viridis')
plt.show()

#plt.savefig("./figure_10sh-1")
# type(csvData)

# %%
colors = {'5':'red', '10':'blue', '15':'green', '20':'yellow', '25':'hotpink'}

n = df['nb_shards']
x = df['nb_requests']
y = df['accuracy']
z = df['retraining_time']

#df['nb_shards'] = np.random.choice(z, 80)
#ax.set_xlabel('nb_request')
#ax.set_ylabel('accuracy')

sns.scatterplot(x, z, hue=df['nb_shards'], cmap='viridis')
plt.show()

# %% [markdown]
# Plot nb_request vs accuracy

# %%
colors = {'5':'red', '10':'blue', '15':'green', '20':'yellow', '25':'hotpink'}

n = df['nb_shards']
x = df['nb_requests']
y = df['accuracy']
z = df['retraining_time']

df['nb_shards'] = np.random.choice(z, 79)
#ax.set_xlabel('nb_request')
#ax.set_ylabel('accuracy')

sns.scatterplot(n, y, hue=df['nb_shards'], cmap='viridis')
plt.show()
